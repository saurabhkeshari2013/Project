# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('goldstock.csv', parse_dates=['Date'])

# %%
df
# Out:
#       Unnamed: 0       Date   Close    Volume    Open    High     Low
# 0              0 2024-01-19  2029.3  166078.0  2027.4  2041.9  2022.2
# 1              1 2024-01-18  2021.6  167013.0  2009.1  2025.6  2007.7
# 2              2 2024-01-17  2006.5  245194.0  2031.7  2036.1  2004.6
# 3              3 2024-01-16  2030.2  277995.0  2053.4  2062.8  2027.6
# 4              4 2024-01-12  2051.6  250946.0  2033.2  2067.3  2033.1
# ...          ...        ...     ...       ...     ...     ...     ...
# 2506        2528 2014-01-28  1250.5   81426.0  1254.9  1261.9  1248.0
# 2507        2529 2014-01-27  1263.5   63419.0  1269.9  1280.1  1252.0
# 2508        2530 2014-01-24  1264.5   34998.0  1264.3  1273.2  1256.9
# 2509        2531 2014-01-23  1262.5   41697.0  1235.1  1267.1  1230.8
# 2510        2532 2014-01-22  1238.6   80262.0  1240.5  1243.5  1235.5
#
# [2511 rows x 7 columns]

# %%
df.shape
# Out:
# (2511, 7)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2511 entries, 0 to 2510
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  2511 non-null   int64
#  1   Date        2511 non-null   datetime64[ns]
#  2   Close       2511 non-null   float64
#  3   Volume      2511 non-null   float64
#  4   Open        2511 non-null   float64
#  5   High        2511 non-null   float64
#  6   Low         2511 non-null   float64
# dtypes: datetime64[ns](1), float64(5), int64(1)
# memory usage: 137.4 KB

# %%
# dropping unnecessary column 

df.drop(columns=["Unnamed: 0"], inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2511 entries, 0 to 2510
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    2511 non-null   datetime64[ns]
#  1   Close   2511 non-null   float64
#  2   Volume  2511 non-null   float64
#  3   Open    2511 non-null   float64
#  4   High    2511 non-null   float64
#  5   Low     2511 non-null   float64
# dtypes: datetime64[ns](1), float64(5)
# memory usage: 117.8 KB

# %%
df.isna().sum()
# Out:
# Date      0
# Close     0
# Volume    0
# Open      0
# High      0
# Low       0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 18

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
# Statistical Summary 
df.describe()
# Out:
#                                 Date        Close         Volume         Open  \
# count                           2493  2493.000000    2493.000000  2493.000000
# mean   2019-01-09 21:15:57.400721920  1496.354272  186034.698355  1496.342479
# min              2014-01-22 00:00:00  1049.600000       1.000000  1051.500000
# 25%              2016-07-13 00:00:00  1248.600000  126411.000000  1248.500000
# 50%              2019-01-04 00:00:00  1331.400000  175222.000000  1332.000000
# 75%              2021-06-28 00:00:00  1803.800000  234908.000000  1803.800000
# max              2024-01-19 00:00:00  2093.100000  787217.000000  2094.400000
# std                              NaN   298.575898   97739.426777   298.860270
#
#               High          Low
# count  2493.000000  2493.000000
# mean   1506.056839  1486.518091
# min    1062.700000  1045.400000
# 25%    1256.600000  1241.700000
# 50%    1340.900000  1324.500000
# 75%    1813.900000  1791.800000
# max    2098.200000  2074.600000
# ...

# %% [markdown]
# # Visualisation

# %%
# plotting boxplot to visualize the outliers

for col in df.columns:
    if df[col].dtype=='float64':
         plt.figure(figsize=(5,2))
         sns.boxplot(df[col])
         plt.xlabel(col)
         plt.ylabel('Count')
         plt.show()

# %%
# Inference:- only Trading Volume has Outliers.

# %%
# Visualize the 'Close' column
plt.figure(figsize=(14, 4))
plt.plot(df['Date'], df['Close'], label='Closing Price')
plt.title('Gold Closing Prices Over Time')
plt.xlabel('Date')
plt.ylabel('Price (USD)')
plt.legend()
plt.show()

# %%
# Visualize the 'Volume' column
plt.figure(figsize=(14, 4))
plt.plot(df['Date'], df['Volume'], color='orange', label='Trading Volume')
plt.title('Gold Trading Volume Over Time')
plt.xlabel('Date')
plt.ylabel('Volume')
plt.legend()
plt.show()

# %%
# Visualize the 'Open' column
plt.figure(figsize=(14, 4))
plt.plot(df['Date'], df.Open, color='green',label='Opening Price')
plt.title('Gold Opening Price Over Time')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.show()

# %%
# Visualize the 'High' column
plt.figure(figsize=(14, 4))
plt.plot(df['Date'], df.High, color='red',label='Highest Price')
plt.title('Highest Gold Price Over Time')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.show()

# %%
# Visualize the 'Low' column
plt.figure(figsize=(14, 4))
plt.plot( df['Date'],df['Low'], color='purple',label='Lowest Price')
plt.title('Lowest Gold Price Over Time')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.show()

# %%
df['Year']=df['Date'].dt.year

# %%
df['Year']
# Out:
# 0       2024
# 1       2024
# 2       2024
# 3       2024
# 4       2024
#         ...
# 2506    2014
# 2507    2014
# 2508    2014
# 2509    2014
# 2510    2014
# Name: Year, Length: 2493, dtype: int32

# %%
sns.barplot(x=df['Year'],y=df['Close'])
plt.title('Closing Price Over Time')
plt.show()

# %%
sns.barplot(x=df['Year'],y=df['Open'])
plt.title('Opening Price Over Time')
plt.show()

# %%
sns.barplot(x=df['Year'],y=df['High'])
plt.title('Highest Gold Price Over Time')
plt.show()

# %%
sns.barplot(x=df['Year'],y=df['Low'])
plt.title('Lowest Gold Price Over Time')
plt.show()

# %%
# check for normality in data

# %%
plt.figure(figsize=[8,4])
sns.distplot(df['Close'], color='g',hist_kws=dict(edgecolor="black", linewidth=2), bins=30)
plt.title('Closing Price')
plt.show()

# %%
plt.figure(figsize=[8,4])
sns.distplot(df['Open'], color='r',hist_kws=dict(edgecolor="black", linewidth=2), bins=30)
plt.title('Opening Price')
plt.show()

# %%
plt.figure(figsize=[8,4])
sns.distplot(df['High'], color='b',hist_kws=dict(edgecolor="black", linewidth=2), bins=30)
plt.title('Highest Price')
plt.show()

# %%
plt.figure(figsize=[8,4])
sns.distplot(df['Low'], color='y',hist_kws=dict(edgecolor="black", linewidth=2), bins=30)
plt.title('Lowest Price')
plt.show()

# %%
# Inference : from above plot, we can see Open, Close, High,Low columns have similar distribusion.

# %%
df.head()
# Out:
#         Date   Close    Volume    Open    High     Low  Year
# 0 2024-01-19  2029.3  166078.0  2027.4  2041.9  2022.2  2024
# 1 2024-01-18  2021.6  167013.0  2009.1  2025.6  2007.7  2024
# 2 2024-01-17  2006.5  245194.0  2031.7  2036.1  2004.6  2024
# 3 2024-01-16  2030.2  277995.0  2053.4  2062.8  2027.6  2024
# 4 2024-01-12  2051.6  250946.0  2033.2  2067.3  2033.1  2024

# %%
df.drop(columns='Year', inplace=True)

# %%
df.corr()
# Out:
#             Date     Close    Volume      Open      High       Low
# Date    1.000000  0.890140  0.101418  0.890042  0.888888  0.891561
# Close   0.890140  1.000000  0.023903  0.998997  0.999526  0.999575
# Volume  0.101418  0.023903  1.000000  0.028158  0.031968  0.019379
# Open    0.890042  0.998997  0.028158  1.000000  0.999458  0.999385
# High    0.888888  0.999526  0.031968  0.999458  1.000000  0.999249
# Low     0.891561  0.999575  0.019379  0.999385  0.999249  1.000000

# %%
sns.heatmap(df.corr(),annot=True,cmap='YlGnBu')
# Out:
# <Axes: >

# %%
# Inference:- closing ,opening , highest and lowest price are highly correlated with date.

# %%
# Decompose the time series into its trend, seasonal, and residual components

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

# %%
decomposition = seasonal_decompose(df['Close'], period=365)  # Assuming yearly seasonality
print(decomposition.plot())
# Out:
# Figure(640x480)

# %%
# from the above plot, after analyzed the trend, we can say, it has down trend.

# %% [markdown]
# # Model building

# %%
# Model building by fb prophet

# %%
from prophet import Prophet

# %%
df
# Out:
#            Date   Close    Volume    Open    High     Low
# 0    2024-01-19  2029.3  166078.0  2027.4  2041.9  2022.2
# 1    2024-01-18  2021.6  167013.0  2009.1  2025.6  2007.7
# 2    2024-01-17  2006.5  245194.0  2031.7  2036.1  2004.6
# 3    2024-01-16  2030.2  277995.0  2053.4  2062.8  2027.6
# 4    2024-01-12  2051.6  250946.0  2033.2  2067.3  2033.1
# ...         ...     ...       ...     ...     ...     ...
# 2506 2014-01-28  1250.5   81426.0  1254.9  1261.9  1248.0
# 2507 2014-01-27  1263.5   63419.0  1269.9  1280.1  1252.0
# 2508 2014-01-24  1264.5   34998.0  1264.3  1273.2  1256.9
# 2509 2014-01-23  1262.5   41697.0  1235.1  1267.1  1230.8
# 2510 2014-01-22  1238.6   80262.0  1240.5  1243.5  1235.5
#
# [2493 rows x 6 columns]

# %%
df_close= df[['Date','Close']]
df_close
# Out:
#            Date   Close
# 0    2024-01-19  2029.3
# 1    2024-01-18  2021.6
# 2    2024-01-17  2006.5
# 3    2024-01-16  2030.2
# 4    2024-01-12  2051.6
# ...         ...     ...
# 2506 2014-01-28  1250.5
# 2507 2014-01-27  1263.5
# 2508 2014-01-24  1264.5
# 2509 2014-01-23  1262.5
# 2510 2014-01-22  1238.6
#
# [2493 rows x 2 columns]

# %%
df_open= df[['Date','Open']]
df_open
# Out:
#            Date    Open
# 0    2024-01-19  2027.4
# 1    2024-01-18  2009.1
# 2    2024-01-17  2031.7
# 3    2024-01-16  2053.4
# 4    2024-01-12  2033.2
# ...         ...     ...
# 2506 2014-01-28  1254.9
# 2507 2014-01-27  1269.9
# 2508 2014-01-24  1264.3
# 2509 2014-01-23  1235.1
# 2510 2014-01-22  1240.5
#
# [2493 rows x 2 columns]

# %%
# Lets do forecasting for closing price

# %%
# renaming the columns-- 'ds' and 'y'

# %%
df_close.rename(columns={'Date':'ds', 'Close':'y'}, inplace=True)
df_close
# Out:
#              ds       y
# 0    2024-01-19  2029.3
# 1    2024-01-18  2021.6
# 2    2024-01-17  2006.5
# 3    2024-01-16  2030.2
# 4    2024-01-12  2051.6
# ...         ...     ...
# 2506 2014-01-28  1250.5
# 2507 2014-01-27  1263.5
# 2508 2014-01-24  1264.5
# 2509 2014-01-23  1262.5
# 2510 2014-01-22  1238.6
#
# [2493 rows x 2 columns]

# %%
# Model building

# %%
# Split your data into training and testing sets
train_size = int(0.8 * len(df_close)) 
train_size
# Out:
# 1994

# %%
train_df = df_close[:train_size]
test_df = df_close[train_size:]

# %%
train_df
# Out:
#              ds       y
# 0    2024-01-19  2029.3
# 1    2024-01-18  2021.6
# 2    2024-01-17  2006.5
# 3    2024-01-16  2030.2
# 4    2024-01-12  2051.6
# ...         ...     ...
# 2007 2016-01-21  1098.2
# 2008 2016-01-20  1106.2
# 2009 2016-01-19  1089.1
# 2010 2016-01-15  1090.7
# 2011 2016-01-14  1073.6
#
# [1994 rows x 2 columns]

# %%
model=Prophet(interval_width=0.95)

# %%
model.fit(train_df)
# Out:
# 00:16:55 - cmdstanpy - INFO - Chain [1] start processing
# 00:17:01 - cmdstanpy - INFO - Chain [1] done processing

# %%
# Make predictions on the test data
future = model.make_future_dataframe(periods=len(test_df))

# %%
future.tail(10)
# Out:
#              ds
# 2483 2025-05-23
# 2484 2025-05-24
# 2485 2025-05-25
# 2486 2025-05-26
# 2487 2025-05-27
# 2488 2025-05-28
# 2489 2025-05-29
# 2490 2025-05-30
# 2491 2025-05-31
# 2492 2025-06-01

# %%
forecast=model.predict(future)

# %%
forecast[['ds','yhat','yhat_lower','yhat_upper']].tail(10)
# Out:
#              ds         yhat   yhat_lower   yhat_upper
# 2483 2025-05-23  2327.380786  1156.507174  3445.711764
# 2484 2025-05-24  2283.292123  1121.903727  3414.612496
# 2485 2025-05-25  2283.625998  1114.633045  3431.017346
# 2486 2025-05-26  2327.775886  1142.367591  3453.490203
# 2487 2025-05-27  2328.698800  1115.152654  3470.595753
# 2488 2025-05-28  2328.568502  1151.750823  3477.551853
# 2489 2025-05-29  2329.530854  1141.808094  3458.477881
# 2490 2025-05-30  2329.038581  1151.228899  3484.949125
# 2491 2025-05-31  2284.630070  1074.795891  3427.903489
# 2492 2025-06-01  2284.664415  1075.581441  3443.172935

# %%
# Extract actual and predicted values
actual_values = test_df['y'].values
predicted_values = forecast['yhat'][-len(test_df):].values

# %%
actual_values
# Out:
# array([1087.1, 1085.2, 1096.2, 1097.9, 1107.8, 1091.9, 1078.4, 1075.2,
#        1060.2, 1059.8, 1068. , 1068.3, 1075.9, 1068.3, 1074.1, 1080.6,
#        1065. , 1049.6, 1076.8, 1061.6, 1063.4, 1075.7, 1072. , 1076.5,
#        1075.3, 1075.2, 1084.1, 1061.2, 1053.8, 1063.5, 1065.3, 1056.2,
#        1069.7, 1073.3, 1066.6, 1076.3, 1077.9, 1068.7, 1068.6, 1083.6,
#        1080.9, 1081. , 1084.9, 1088.5, 1088.1, 1087.7, 1104.2, 1106.2,
#        1114.1, 1135.9, 1141.4, 1147.3, 1176.1, 1165.8, 1166.2, 1162.8,
#        1166.1, 1167.1, 1177.5, 1172.8, 1183.1, 1187.5, 1179.8, 1165.4,
#        1164.5, 1155.9, 1144.3, 1148.7, 1146.4, 1137.6, 1136.6, 1113.7,
#        1115.2, 1126.8, 1131.7, 1145.6, 1153.8, 1131.5, 1124.8, 1132.8,
#        1137.8, 1117. , 1119. , 1102.6, 1107.7, 1103.3, 1109.3, 1102. ,
#        1121. , 1121.4, 1124.5, 1133.6, 1139.8, 1132.5, 1134. , 1122.6,
#        1124.6, 1138.3, 1153.6, 1159.6, 1153.2, 1127.9, 1116.9, 1118.4,
# ...

# %%
predicted_values
# Out:
# array([2004.89275492, 2005.72324442, 2050.45464863, 2052.04676057,
#        2052.67304116, 2054.47627499, 2054.9037014 , 2011.4862489 ,
#        2012.57406255, 2057.5565826 , 2059.38444306, 2060.22307585,
#        2062.20851318, 2062.78261637, 2019.47235817, 2020.62534975,
#        2065.62987281, 2067.43668986, 2068.21252359, 2070.09570421,
#        2070.5312205 , 2027.04980912, 2028.00328159, 2072.78435719,
#        2074.34828282, 2074.86613762, 2076.48032782, 2076.63951266,
#        2032.87760031, 2033.54901563, 2078.04850984, 2079.33279269,
#        2079.57388365, 2080.91468461, 2080.80401074, 2036.77571335,
#        2037.18409033, 2081.42384744, 2082.45188375, 2082.44079034,
#        2083.53455761, 2083.18372063, 2038.92457035, 2039.11462081,
#        2083.1525912 , 2084.0001733 , 2083.83547163, 2084.80861151,
#        2084.37674615, 2040.08309325, 2040.29219573, 2084.4096714 ,
#        2085.40372853, 2085.45834309, 2086.72860097, 2086.67544563,
# ...

# %% [markdown]
# # Model Evaluation for Closing price

# %%
from sklearn.metrics import mean_squared_error

# %%
mse_close = mean_squared_error(actual_values, predicted_values)
print("Mean Squared Error (MSE) for closing price:", mse_close)
# Out:
# Mean Squared Error (MSE) for closing price: 919568.8209621175

# %%
rmse_close = np.sqrt(mse_close)

# %%
rmse_close
# Out:
# 958.9415107096561

# %%
df_close_plot=model.plot(forecast)

# %%
df_close_plot=model.plot_components(forecast)

# %%
# Lets do forecasting for Opening price

# %%
df_open.rename(columns={'Date':'ds', 'Open':'y'}, inplace=True)
df_open
# Out:
#              ds       y
# 0    2024-01-19  2027.4
# 1    2024-01-18  2009.1
# 2    2024-01-17  2031.7
# 3    2024-01-16  2053.4
# 4    2024-01-12  2033.2
# ...         ...     ...
# 2506 2014-01-28  1254.9
# 2507 2014-01-27  1269.9
# 2508 2014-01-24  1264.3
# 2509 2014-01-23  1235.1
# 2510 2014-01-22  1240.5
#
# [2493 rows x 2 columns]

# %%
# Model building  for opening price

# %%
# Split your data into training and testing sets
train_size = int(0.8 * len(df_open)) 
train_size
# Out:
# 1994

# %%
train_df = df_open[:train_size]
test_df = df_open[train_size:]

# %%
train_df
# Out:
#              ds       y
# 0    2024-01-19  2027.4
# 1    2024-01-18  2009.1
# 2    2024-01-17  2031.7
# 3    2024-01-16  2053.4
# 4    2024-01-12  2033.2
# ...         ...     ...
# 2007 2016-01-21  1100.9
# 2008 2016-01-20  1087.3
# 2009 2016-01-19  1089.0
# 2010 2016-01-15  1089.3
# 2011 2016-01-14  1093.6
#
# [1994 rows x 2 columns]

# %%
model2=Prophet(interval_width=0.95)

# %%
model2.fit(train_df)
# Out:
# 00:17:11 - cmdstanpy - INFO - Chain [1] start processing
# 00:17:14 - cmdstanpy - INFO - Chain [1] done processing

# %%
# Make predictions on the test data
future2 = model2.make_future_dataframe(periods=len(test_df))

# %%
future2.tail(10)
# Out:
#              ds
# 2483 2025-05-23
# 2484 2025-05-24
# 2485 2025-05-25
# 2486 2025-05-26
# 2487 2025-05-27
# 2488 2025-05-28
# 2489 2025-05-29
# 2490 2025-05-30
# 2491 2025-05-31
# 2492 2025-06-01

# %%
forecast_open=model2.predict(future2)

# %%
forecast_open[['ds','yhat','yhat_lower','yhat_upper']].tail(10)
# Out:
#              ds         yhat   yhat_lower   yhat_upper
# 2483 2025-05-23  2330.977741  1184.180178  3495.387362
# 2484 2025-05-24  2304.045258  1197.007101  3473.048968
# 2485 2025-05-25  2304.431981  1201.148836  3469.237160
# 2486 2025-05-26  2332.988528  1212.362053  3482.385191
# 2487 2025-05-27  2332.445070  1184.731010  3530.818513
# 2488 2025-05-28  2332.808985  1155.557993  3532.992005
# 2489 2025-05-29  2333.389810  1185.055673  3506.449844
# 2490 2025-05-30  2333.023270  1200.604027  3544.428718
# 2491 2025-05-31  2305.774569  1180.499706  3518.373521
# 2492 2025-06-01  2305.852159  1136.193107  3481.055269

# %%
# Extract actual and predicted values
actual_values = test_df['y'].values
predicted_values = forecast_open['yhat'][-len(test_df):].values

# %%
actual_values
# Out:
# array([1086.8, 1094. , 1103.6, 1108.8, 1093.7, 1076.8, 1073.5, 1061.5,
#        1060.6, 1068.2, 1068.2, 1068.6, 1069.6, 1069.5, 1070.8, 1078. ,
#        1051.5, 1072.2, 1060.3, 1060.4, 1073. , 1071.4, 1071.7, 1074.3,
#        1069.7, 1085.5, 1062. , 1053.5, 1067.9, 1064.6, 1056. , 1071. ,
#        1070.6, 1067.6, 1072.7, 1079.7, 1079.5, 1070.2, 1082.4, 1087.9,
#        1083.5, 1085.4, 1088.5, 1089. , 1089.1, 1103.2, 1103.6, 1117.4,
#        1132.9, 1141.3, 1146.6, 1156.1, 1166.7, 1163. , 1163.8, 1165.9,
#        1166.8, 1175.5, 1170.6, 1176.9, 1182.5, 1184. , 1168.2, 1162.8,
#        1155. , 1138.1, 1145. , 1146.5, 1134.7, 1137. , 1112.5, 1114.5,
#        1127.2, 1131.4, 1145. , 1151. , 1130. , 1123.8, 1132.6, 1138.7,
#        1130. , 1118.7, 1104.4, 1107.1, 1107. , 1110.2, 1105.7, 1121. ,
#        1118.1, 1123. , 1133.2, 1139. , 1133.8, 1132.7, 1124.4, 1124.4,
#        1139.9, 1155.7, 1160.2, 1153.3, 1133.3, 1117.2, 1117.2, 1113.5,
# ...

# %%
predicted_values
# Out:
# array([2022.94853577, 2023.84987311, 2052.97571021, 2053.06170676,
#        2054.11774898, 2055.4530922 , 2055.90069109, 2029.52085024,
#        2030.51542485, 2059.73523146, 2059.9083771 , 2061.03822331,
#        2062.42868103, 2062.9086435 , 2036.53568849, 2037.51027969,
#        2066.68312913, 2066.78343246, 2067.81669876, 2069.08987697,
#        2069.43559369, 2042.9156416 , 2043.73495728, 2072.74875888,
#        2072.69056444, 2073.56982081, 2074.69685293, 2074.90695476,
#        2048.26376697, 2048.97318379, 2077.89046257, 2077.74825761,
#        2078.55430758, 2079.61648409, 2079.76701911, 2053.06605075,
#        2053.71572387, 2082.56751123, 2082.35046874, 2083.06914544,
#        2084.02884688, 2084.06006076, 2057.2221762 , 2057.71772536,
#        2086.39980659, 2086.00039727, 2086.52827308, 2087.29422992,
#        2087.13541691, 2060.11891275, 2060.45577716, 2089.00824118,
#        2088.51775054, 2089.0025865 , 2089.7827691 , 2089.70406084,
# ...

# %% [markdown]
# # Model Evaluation for Opening price

# %%
mse_open = mean_squared_error(actual_values, predicted_values)
print("Mean Squared Error (MSE) for opening price:", mse_open)
# Out:
# Mean Squared Error (MSE) for opening price: 933361.7589492846

# %%
rmse_open = np.sqrt(mse_open)

# %%
rmse_open
# Out:
# 966.1064946212113

# %%
df_open_plot=model2.plot(forecast_open)

# %%
df_open_plot=model2.plot_components(forecast_open)

# %%
# comparing the MSE & RMSE of both data

# %%
print("Mean Squared Error (MSE) for closing price:", mse_close)
print("Mean Squared Error (MSE) for opening price:", mse_open)
# Out:
# Mean Squared Error (MSE) for closing price: 919568.8209621175
# Mean Squared Error (MSE) for opening price: 933361.7589492846

# %%
print("Root Mean Squared Error (RMSE) for closing price:", rmse_close)
print("Root Mean Squared Error (RMSE) for opening price:", rmse_open)
# Out:
# Root Mean Squared Error (RMSE) for closing price: 958.9415107096561
# Root Mean Squared Error (RMSE) for opening price: 966.1064946212113
